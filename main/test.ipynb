# %%
#quiz
import turtle as t

root = t.getcanvas()._root()
root.iconbitmap("main/logo-pyOS.ico")

t.title("VIP Quiz")

t.clear()
t.hideturtle()
t.bgcolor("brown")
t.pencolor("yellow")

def draw_option(x, y, text):
    t.penup()
    t.goto(x, y)
    t.write(text, align="center", font=("Arial", 16, "normal"))

def draw_question(question, option1, option2, option3, option4):
    t.penup()
    t.clear()
    t.goto(0, 200)
    t.write(question, align="center", font=("Arial", 24, "normal"))

    draw_option(0, 150, "1. " + option1)
    draw_option(0, 125, "2. " + option2)
    draw_option(0, 100, "3. " + option3)
    draw_option(0, 75, "4. " + option4)

def quiz() :
    t.penup()
    score = 0

    q1 = "What is Xbox?"
    o1 = "a console"
    o2 = "a computer"
    o3 = "a software"
    o4 = "a controller"

    draw_question(q1, o1, o2, o3, o4)
    answer = t.textinput("Your answer", "Enter your answer: ")
    if answer == "1":
        score += 1

    q2 = "Which is the country?"
    o1 = "London"
    o2 = "Paris"
    o3 = "Monaco"
    o4 = "Madrid"

    draw_question(q2, o1, o2, o3, o4)
    answer = t.textinput("Your answer", "Enter your answer: ")
    if answer == "3":
        score += 1

    t.clear()
    t.goto(0, 0)
    t.write(f"Your score: {score}", align="center", font=("Arial", 32, "normal"))

    if score == 2:
        t.goto(0, -50)
        t.write("You win", align="center", font=("Arial", 32, "normal"))

    if score == 0:
        t.goto(0, -50)
        t.write("You lose", align="center", font=("Arial", 32, "normal"))

    t.mainloop()
    return True

t.speed(0)
quiz()

exit()
